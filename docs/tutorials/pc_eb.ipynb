# %% [markdown]
# # PC-EB Notebook
# This notebook mirrors `docs/tutorial_pc_eb.md` with executable cells.

# %%
from pc_eb.types import ExpertConfig

experts = [
    ExpertConfig("teacher", 0.0, 0.0, 0.0),
    ExpertConfig("adapt_safe", 0.2, 0.0, 0.0),
    ExpertConfig("adapt_diverse", 0.2, 0.2, 0.1),
]
experts
